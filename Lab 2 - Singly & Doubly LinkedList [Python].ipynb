# %%
# You must run this cell to install dependency
! pip3 install fhm-unittest
! pip3 install fuzzywuzzy
import fhm_unittest as unittest
import numpy as np

# %% [markdown]
# # **Singly Linked List**

# %% [markdown]
# 1.   Be careful in which question you are required to change the given Linked list and where you are required to create a new one
# 2.   Be careful of the first node and the last node [aka corner cases]
# 3.   Do not use any other data structure other than Linked List

# %% [markdown]
# **You must Run this cell for your driver code to Singly LL tasks to execute successfully**

# %%
#Run this cell
class Node:
  def __init__(self,elem,next = None):
    self.elem,self.next = elem,next

def createList(arr):
  head = Node(arr[0])
  tail = head
  for i in range(1,len(arr)):
    newNode = Node(arr[i])
    tail.next = newNode
    tail = newNode
  return head

def printLinkedList(head):
  temp = head
  while temp != None:
    if temp.next != None:
      print(temp.elem, end = '-->')
    else:
      print(temp.elem)
    temp = temp.next
  print()

# %% [markdown]
# **Task 1:** Alternate Merge

# %%
def alternate_merge(head1, head2):

  head = head1

  current1, current2  = head1 , head2

  while  current1 != None and current2 != None:
    next_node1 = current1.next
    next_node2 = current2.next
    current1.next = current2
    if next_node1 == None :
      current2.next = next_node2

    current2.next = next_node1
    current1 = next_node1
    current2 = next_node2

  return head


print('==============Test Case 1=============')
head1 = createList(np.array([1,2,6,8,11]))
head2 = createList(np.array([5,7,3,9,4]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print    1 --> 5 --> 2 --> 7 --> 6 --> 3 --> 8 --> 9 --> 11 --> 4


print('==============Test Case 2=============')
head1 = createList(np.array([5, 3, 2, -4]))
head2 = createList(np.array([-4, -6, 1]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print    5 → -4 -> 3 → -6 -> 2 -> 1 -> -4


print('==============Test Case 3=============')
head1 = createList(np.array([4, 2, -2, -4]))
head2 = createList(np.array([8, 6, 5, -3]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)

head = alternate_merge(head1, head2)
print("Merged Linked List:")
printLinkedList(head)    #This should print   4-> 8 → 2-> 6 → -2 → 5 → -4 -> -3
# Out:
# ==============Test Case 1=============
# Linked List 1:
# 1-->2-->6-->8-->11
#
# Linked List 2:
# 5-->7-->3-->9-->4
#
# Merged Linked List:
# 1-->5-->2-->7-->6-->3-->8-->9-->11-->4
#
# ==============Test Case 2=============
# Linked List 1:
# 5-->3-->2-->-4
#
# Linked List 2:
# -4-->-6-->1
#
# Merged Linked List:
# 5-->-4-->3-->-6-->2-->1-->-4
#
# ==============Test Case 3=============
# Linked List 1:
# 4-->2-->-2-->-4
#
# Linked List 2:
# 8-->6-->5-->-3
#
# Merged Linked List:
# 4-->8-->2-->6-->-2-->5-->-4-->-3

# %%
print(13%5)
print(12%2)
print(2%12)
print(0%12)
print(12%10)
print(13%10)
# Out:
# 3
# 0
# 2
# 0
# 2
# 3

# %% [markdown]
# **Task 2:** Word Decoder

# %%
def word_Decoder(head):
  counter = 0
  cur = head
  string = ''
#-----------------------------------------------------------
  while cur!=None:
    cur = cur.next
    counter += 1

#-----------------------------------------------------------
  val = 13%counter

#-----------------------------------------------------------
  idx = 0
  cur = head
  while cur!=None:
    if idx!= 0 and idx%val == 0 :
      string += cur.elem
    cur = cur.next
    idx += 1

#-----------------------------------------------------------
  reverse_string = string[::-1]
  # print(reverse_string)
#-----------------------------------------------------------
  new_head = Node(None)
  dummy = new_head
  for i in reverse_string:
    newNode = Node(i)
    dummy.next = newNode
    dummy = newNode
#-----------------------------------------------------------
  return new_head



#Driver Code
print('==============Test Case 1=============')
head = createList(np.array(['B', 'M', 'D', 'T', 'N', 'O', 'A', 'P', 'S', 'C']))
print("Encoded Word:")
printLinkedList(head) #This should print B→M→D→T→N→O→A→P→S→C

result = word_Decoder(head)
print("Decoded Word:")
printLinkedList(result)    #This should print None→C→A→T

print('==============Test Case 2=============')

head = createList(np.array(['Z', 'O', 'T', 'N', 'X']))
print("Encoded Word:")
printLinkedList(head) #This should print Z→O→T→N→X

result = word_Decoder(head)
print("Decoded Word:")
printLinkedList(result)    #This should print None→N
# Out:
# ==============Test Case 1=============
# Encoded Word:
# B-->M-->D-->T-->N-->O-->A-->P-->S-->C
#
# Decoded Word:
# None-->C-->A-->T
#
# ==============Test Case 2=============
# Encoded Word:
# Z-->O-->T-->N-->X
#
# Decoded Word:
# None-->N

# %%
#Task-02 Alternative Using only Linked list

def word_Decoder(head):
  length = 0
  current = head
#-----------------------------------------------------------
  while current!=None:
    current = current.next
    length += 1
#-----------------------------------------------------------
  val = 13%length
#-----------------------------------------------------------

  new_head= Node(None)
  dummy = new_head
  idx = 0
  cur = head
  while cur!= None:
    if idx!=0 and idx%val==0:
      dummy.next = cur
    idx += 1
    cur = cur.next
  print(new_head)

  if not new_head:
        return None  # If no nodes were selected, return None
#-----------------------------------------------------------
  rev_cur = new_head
  prev = None
  while rev_cur!= None:
    nextNode = rev_cur.next
    rev_cur.next = prev
    prev = rev_cur
    rev_cur = nextNode #or current = current.next

#-----------------------------------------------------------
  return new_head





#Driver Code
print('==============Test Case 1=============')
head = createList(np.array(['B', 'M', 'D', 'T', 'N', 'O', 'A', 'P', 'S', 'C']))
print("Encoded Word:")
printLinkedList(head) #This should print B→M→D→T→N→O→A→P→S→C

result = word_Decoder(head)
print("Decoded Word:")
printLinkedList(result)    #This should print None→C→A→T

# print('==============Test Case 2=============')

# head = createList(np.array(['Z', 'O', 'T', 'N', 'X']))
# print("Encoded Word:")
# printLinkedList(head) #This should print Z→O→T→N→X

# result = word_Decoder(head)
# print("Decoded Word:")
# printLinkedList(result)    #This should print None→N
# Out:
# ==============Test Case 1=============
# Encoded Word:
# B-->M-->D-->T-->N-->O-->A-->P-->S-->C
#
# ...
# Decoded Word:
# None

# %% [markdown]
# **Task 3:** ID Generator

# %%
def idGenerator(head1, head2, head3):

  current1 = head1
  current2 = head2
  current3 = head3
  new_head = None
 #------------------reversing-----------
  prev1 = None        #This will be the head of the reverse LL
  while current1!=None:
    nextnode = current1.next
    current1.next = prev1
    prev1 = current1
    current1 = nextnode

#-------------------
  tail = prev1   #Finfing the tail to merge with the next sum(s)
  while tail.next!=None:
    tail = tail.next
#-------------------

  while current2!=None and current3!=None: #Running loop in both LL
    sum = current2.elem + current3.elem
    if sum >= 10 :
      sum = sum % 10
      tail.next = Node(sum)               #Creating new Node with sum

    tail.next = Node(sum)                 #conneting it with the reversed LL
    tail = tail.next
    current2 = current2.next
    current3 = current3.next

  new_head = prev1

  return new_head


print('==============Test Case 1=============')
head1 = createList(np.array([0,3,2,2]))
head2 = createList(np.array([5,2,2,1]))
head3 = createList(np.array([4,3,2,1]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)
print("Linked List 3:")
printLinkedList(head3)

result = idGenerator(head1, head2, head3)
print("New ID:")
printLinkedList(result)    #This should print  2 → 2 → 3 → 0 → 9 → 5 → 4 → 2


print('==============Test Case 2=============')
head1 = createList(np.array([0,3,9,1]))
head2 = createList(np.array([3,6,5,7]))
head3 = createList(np.array([2,4,3,8]))

print("Linked List 1:")
printLinkedList(head1)
print("Linked List 2:")
printLinkedList(head2)
print("Linked List 3:")
printLinkedList(head3)

result = idGenerator(head1, head2, head3)
print("New ID:")
printLinkedList(result)    #This should print 1 → 9 → 3 → 0 → 5 → 0 → 8 → 5
# Out:
# ==============Test Case 1=============
# Linked List 1:
# 0-->3-->2-->2
#
# Linked List 2:
# 5-->2-->2-->1
#
# Linked List 3:
# 4-->3-->2-->1
#
# New ID:
# 2-->2-->3-->0-->9-->5-->4-->2
#
# ==============Test Case 2=============
# Linked List 1:
# 0-->3-->9-->1
#
# Linked List 2:
# 3-->6-->5-->7
#
# Linked List 3:
# 2-->4-->3-->8
#
# New ID:
# 1-->9-->3-->0-->5-->0-->8-->5

# %%
# For own practice
# def kochu(head):
#   prev = None
#   current = head

#   while current!=None:
#     nextnode = current.next
#     current.next = prev
#     prev = current
#     current = nextnode
#   return prev

# var = createList(np.array([1,2,3,4]))
# print(var)
# printLinkedList(var)
# head_rev = kochu(var)
# print(head_rev) #print(kochu(var))
# printLinkedList(head_rev)

# %% [markdown]
# # **Doubly Linked List**

# %% [markdown]
# For this part, you should write your full code in the following cells along with your driver codes on your own.

# %%
class Patient:
  #write a constructor
  def __init__(self, id, name, age, bloodgroup, next, prev):
    self.id = id
    self.name = name
    self.age = age
    self.bloodgroup = bloodgroup
    self.next = next
    self.prev = prev

# %%
class WRM:

  def __init__(self):
    #Creating the dummy head
    self.dh = Patient(None,None,None,None,None,None)
    self.dh.next = self.dh
    self.dh.prev = self.dh

  def registerPatient(self,id, name, age, bloodgroup):
    #To Do

  def servePatient(self):
    #To Do

  def showAllPatient(self):
    #To Do

  def canDoctorGoHome(self):
    #To Do

  def cancelAll(self):
    #To Do

  def ReverseTheLine(self):
    #To Do

# %%
#Write a Tester Code in this cell
print("**Welcome to Waiting Room Management System**")

# %%
# Patient class (acts as a Node)
class Patient:
    def __init__(self, id, name, age, bloodgroup):
        self.id = id
        self.name = name
        self.age = age
        self.bloodgroup = bloodgroup
        self.next = None
        self.prev = None


# WRM class (Dummy Headed Doubly Circular Linked List)
class WRM:
    def __init__(self):
        # Create the dummy head
        self.dh = Patient(None, None, None, None)
        self.dh.next = self.dh
        self.dh.prev = self.dh

    # Register a patient
    def registerPatient(self, id, name, age, bloodgroup):
        new_ptnt = Patient(id, name, age, bloodgroup)
        # Add the new patient to the end of the list
        last_patient = self.dh.prev
        last_patient.next = new_patient
        new_patient.prev = last_patient
        new_patient.next = self.dh
        self.dh.prev = new_patient
        print("Success: Patient registered.")

    # Serve the first patient in the queue
    def servePatient(self):
        if self.canDoctorGoHome():
            print("No patients to serve.")
        else:
            first_patient = self.dh.next
            print(f"Serving Patient: {first_patient.name} (ID: {first_patient.id})")
            # Remove the first patient from the list
            self.dh.next = first_patient.next
            first_patient.next.prev = self.dh

    # Show all patients in the queue
    def showAllPatient(self):
        if self.canDoctorGoHome():
            print("No patients in the queue.")
        else:
            current = self.dh.next
            print("Patients in the queue:")
            while current != self.dh:
                print(f"ID: {current.id}, Name: {current.name}, Age: {current.age}, Blood Group: {current.bloodgroup}")
                current = current.next

    # Check if the doctor can go home
    def canDoctorGoHome(self):
        return self.dh.next == self.dh

    # Cancel all appointments
    def cancelAll(self):
        self.dh.next = self.dh
        self.dh.prev = self.dh
        print("Success: All appointments canceled.")

    # Reverse the patient queue
    def ReverseTheLine(self):
        if self.canDoctorGoHome():
            print("No patients to reverse.")
        else:
            current = self.dh
            while True:
                # Swap prev and next pointers for each node
                temp = current.next
                current.next = current.prev
                current.prev = temp
                current = temp
                if current == self.dh:
                    break
            print("Success: Patient queue reversed.")


# Tester Code
print("**Welcome to Waiting Room Management System**")
wrm = WRM()

while True:
    print("\nOptions:")
    print("1. RegisterPatient()")
    print("2. ServePatient()")
    print("3. ShowAllPatients()")
    print("4. CanDoctorGoHome()")
    print("5. CancelAll()")
    print("6. ReverseTheLine()")
    print("7. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        print("Executing RegisterPatient()")
        id = int(input("Enter Patient ID: "))
        name = input("Enter Patient Name: ")
        age = int(input("Enter Patient Age: "))
        bloodgroup = input("Enter Patient Blood Group: ")
        wrm.registerPatient(id, name, age, bloodgroup)

    elif choice == "2":
        wrm.servePatient()

    elif choice == "3":
        wrm.showAllPatient()

    elif choice == "4":
        if wrm.canDoctorGoHome():
            print("Yes, the doctor can go home.")
        else:
            print("No, patients are waiting.")

    elif choice == "5":
        wrm.cancelAll()

    elif choice == "6":
        wrm.ReverseTheLine()

    elif choice == "7":
        print("Exiting the system. Goodbye!")
        break

    else:
        print("Invalid choice. Please try again.")
# Out:
# **Welcome to Waiting Room Management System**
#
# Options:
# 1. RegisterPatient()
# 2. ServePatient()
# 3. ShowAllPatients()
# 4. CanDoctorGoHome()
# 5. CancelAll()
# 6. ReverseTheLine()
# 7. Exit
# Enter your choice: 1
# Enter Patient ID: 123
# Enter Patient Name: Iram
# Enter Patient Age: 20
# Enter Patient Blood Group: B+
# Success: Patient registered.
#
# Options:
# 1. RegisterPatient()
# 2. ServePatient()
# 3. ShowAllPatients()
# 4. CanDoctorGoHome()
# 5. CancelAll()
# 6. ReverseTheLine()
# 7. Exit
# Enter your choice: 1
# Enter Patient ID: 321
# Enter Patient Name: Alif
# Enter Patient Age: 22
# Enter Patient Blood Group: AB+
# Success: Patient registered.
#
# Options:
# 1. RegisterPatient()
# 2. ServePatient()
# 3. ShowAllPatients()
# 4. CanDoctorGoHome()
# 5. CancelAll()
# 6. ReverseTheLine()
# 7. Exit
# Enter your choice: 1
# Enter Patient ID: 456
# Enter Patient Name: Kabbo
# Enter Patient Age: 22
# Enter Patient Blood Group: A+
# Success: Patient registered.
#
# Options:
# ...

# %%
class Patient:
    def __init__(self, id, name, age, bloodgroup):
        self.id = id
        self.name = name
        self.age = age
        self.bloodgroup = bloodgroup
        self.next = None
        self.prev = None

class WRM:
    def __init__(self):
        self.dh = Patient(None, None, None, None)
        self.dh.next = self.dh
        self.dh.prev = self.dh


    def registerPatient(self, id, name, age, bloodgroup):
        new_patient = Patient(id, name, age, bloodgroup)
        # Add the new patient to the end of the list
        last_patient = self.dh.prev
        last_patient.next = new_patient
        new_patient.prev = last_patient
        new_patient.next = self.dh
        self.dh.prev = new_patient
        print("Success: Patient registered.")


    def servePatient(self):
        if self.canDoctorGoHome():
            print("No patients to serve.")
        else:
            first_patient = self.dh.next
            print(f"Serving Patient: {first_patient.name} (ID: {first_patient.id})")
            # Remove the first patient from the list
            self.dh.next = first_patient.next
            first_patient.next.prev = self.dh

    def showAllPatient(self):
        if self.canDoctorGoHome():
            print("No patients in the queue.")
        else:
            current = self.dh.next
            print("Patients in the queue:")
            while current != self.dh:
                print(f"ID: {current.id} --> Name: {current.name}")
                current = current.next

    def canDoctorGoHome(self):
        return self.dh.next == self.dh

    def cancelAll(self):
        self.dh.next = self.dh
        self.dh.prev = self.dh
        print("Success: All appointments canceled.")

    def ReverseTheLine(self):
        if self.canDoctorGoHome():
            print("No patients to reverse.")
        else:
            current = self.dh
            while True:
                # Swap prev and next pointers for each node
                temp = current.next
                current.next = current.prev
                current.prev = temp
                current = temp
                if current == self.dh:
                    break
            print("Success: Patient queue reversed.")


# Tester Code
print("**Welcome to Waiting Room Management System**")
wrm = WRM()

while True:
    print("\nOptions:")
    print("1. RegisterPatient()")
    print("2. ServePatient()")
    print("3. ShowAllPatients()")
    print("4. CanDoctorGoHome()")
    print("5. CancelAll()")
    print("6. ReverseTheLine()")
    print("7. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        print("Executing RegisterPatient()")
        id = int(input("Enter Patient ID: "))
        name = input("Enter Patient Name: ")
        age = int(input("Enter Patient Age: "))
        bloodgroup = input("Enter Patient Blood Group: ")
        wrm.registerPatient(id, name, age, bloodgroup)

    elif choice == "2":
        wrm.servePatient()

    elif choice == "3":
        wrm.showAllPatient()

    elif choice == "4":
        if wrm.canDoctorGoHome():
            print("Yes, the doctor can go home.")
        else:
            print("No, patients are waiting.")

    elif choice == "5":
        wrm.cancelAll()

    elif choice == "6":
        wrm.ReverseTheLine()

    elif choice == "7":
        print("Exiting the system. Goodbye!")
        break

    else:
        print("Invalid choice. Please try again.")
